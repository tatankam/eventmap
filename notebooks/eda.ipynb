# %% [markdown]
# ##### Event Data Generator 🏟️
#
# Generate synthetic event data for the Veneto region.
#
# - Random cities, venues, and event types
# - Realistic dates and descriptions
# - Output: `veneto_events.json`

# %%
import json
import random
from datetime import datetime, timedelta


# Veneto cities and villages with multiple venues each (Veneto region only, expanded)
locations = {
    "Venice": [
        "Teatro La Fenice", "Piazza San Marco", "Lido di Venezia", "Murano Glass Museum",
        "Palazzo Ducale", "Gallerie dell'Accademia", "Rialto Bridge", "Ca' Rezzonico",
        "Basilica di San Marco", "Peggy Guggenheim Collection", "Isola di Burano",
        "Scuola Grande di San Rocco", "San Giorgio Maggiore", "Campo Santa Margherita",
        "Jewish Ghetto", "Palazzo Contarini del Bovolo", "Fondazione Querini Stampalia",
        "Ca' d'Oro", "Venetian Arsenal", "Scala Contarini del Bovolo", "Church of San Zaccaria",
        "Palazzo Mocenigo", "Palazzo Grimani", "Campo Santa Maria Formosa", "Sant’Elena Park",
        "Palazzo Querini Stampalia", "Isola di Torcello", "Ghetto Nuovo Synagogue"
    ],
    "Padua": [
        "Stadio Euganeo", "Prato della Valle", "Palazzo della Ragione", "Orto Botanico",
        "Cappella degli Scrovegni", "Basilica di Sant'Antonio", "Scrovegni Chapel",
        "Museo del Precinema", "Palazzo Zabarella", "Church of the Eremitani", "Palazzo Moroni",
        "Botanical Garden of Padua (UNESCO site)", "Civic Museum", "Piazza dei Frutti",
        "Piazza delle Erbe", "Cattedrale di Padova", "Museo Diocesano", "Museo Antoniano",
        "Museo Bottacin", "Palazzo Liviano", "Museo della Padova Ebraica", "Abbazia di Santa Giustina"
    ],
    "Verona": [
        "Arena di Verona", "Verona Exhibition Center", "Piazza Bra", "Juliet's House",
        "Castelvecchio", "Giardino Giusti", "Torre dei Lamberti", "Basilica of San Zeno",
        "Ponte Pietra", "Palazzo Barbieri", "Santa Anastasia Church", "Palazzo della Gran Guardia",
        "Roman Theatre", "Museum of Castelvecchio", "Ponte Scaligero", "Piazza delle Erbe",
        "Piazza dei Signori", "Giardino dell’Arnesa", "Arche Scaligere", "Chiesa di San Fermo Maggiore",
        "Chiesa di San Bernardino", "Palazzo Maffei", "Palazzo Canossa", "Museo Lapidario Maffeiano"
    ],
    "Vicenza": [
        "Piazza dei Signori", "Teatro Olimpico", "Villa La Rotonda", "Basilica Palladiana",
        "Museo Civico di Palazzo Chiericati", "Giardino Salvi", "Palazzo Thiene",
        "Villa Valmarana ai Nani", "Porta Castello", "Santa Corona Church", "Palazzo Chiericati Museum",
        "Palazzo Barbaran da Porto", "Villa Caldogno", "Palazzo Porto", "San Lorenzo Church",
        "Villa Trissino", "Villa Almerico Capra 'La Rotonda'", "Villa Bissari", "Rotonda di Vicenza",
        "Ponte San Michele", "Museo Naturalistico Archeologico", "Palazzo Bonin Longare"
    ],
    "Treviso": [
        "Piazza dei Signori", "Teatro Mario Del Monaco", "Fontane di Treviso", "Villa Revedin",
        "Museo di Santa Caterina", "Isola della Pescheria", "Duomo di Treviso",
        "Museo Bailo", "Porta San Tommaso", "Palazzo dei Trecento", "Parco degli Alberi Parlanti",
        "Villa Pisani", "Church of San Francesco", "Palazzo Bomben", "Villa Giovannelli Colonna",
        "Fontana delle Tette", "Villa Margherita", "Museo Luigi Bailo", "Chiesa di San Nicolò",
        "Villa Corner"
    ],
    "Belluno": [
        "Piazza dei Martiri", "Palazzo dei Rettori", "Museo Civico", "Basilica Cattedrale di San Martino",
        "Palazzo Fulcis", "Porta Dojona", "Chiesa di Santo Stefano", "Parco Nazionale Dolomiti Bellunesi",
        "Ponte della Vittoria", "Torre Civica"
    ],
    "Rovigo": [
        "Piazza Vittorio Emanuele II", "Palazzo Roverella", "Tempio della Beata Vergine del Soccorso",
        "Accademia dei Concordi", "Museo dei Grandi Fiumi", "Palazzo Roncale", "Torre Donà",
        "Chiesa della Beata Vergine del Soccorso", "Teatro Sociale", "Castello di Rovigo"
    ],
    "Chioggia": [
        "Cattedrale di Santa Maria Assunta", "Museo Civico della Laguna Sud", "Corso del Popolo",
        "Torre dell'Orologio", "Mercato del Pesce", "Isola di Pellestrina", "Sottomarina Beach",
        "Ponte Vigo", "Chiesa di San Domenico", "Laguna del Lusenzo"
    ],
    "Mestre": [
        "Parco San Giuliano", "Piazza Ferretto", "Church of San Lorenzo", "Parco Albanese",
        "Villa Querini", "Forte Marghera", "Centro Culturale Candiani", "Torre dell'Orologio",
        "Teatro Toniolo", "Galleria Matteotti"
    ],
    "Jesolo": [
        "Jesolo Beach", "Sea Life Aquarium", "Piazza Mazzini", "Pineta Beach",
        "Aqualandia Waterpark", "Parco Zoo Punta Verde", "Tropicarium Park", "Piazza Brescia",
        "Laguna del Mort", "Museo Civico di Jesolo"
    ],
    "Bassano del Grappa": [
        "Ponte degli Alpini", "Museo Civico", "Piazza Garibaldi", "Castello degli Ezzelini",
        "Villa Angarano", "Museo della Grappa", "Chiesa di San Giovanni Battista",
        "Palazzo Agostinelli", "Villa Recoaro", "Teatro Remondini"
    ],
    "Asolo": [
        "Castello della Regina", "Villa Freya", "Piazza Garibaldi", "Rocca di Asolo",
        "Museo Civico", "Cathedral of Asolo", "Villa Barbaro", "Church of Santa Caterina",
        "Palazzo della Ragione", "Villa Maser"
    ],
    "Cortina d'Ampezzo": [
        "Funivia Faloria", "Basilica Minore dei Santi Filippo e Giacomo", "Museo d'Arte Moderna Mario Rimoldi",
        "Lago di Pianozes", "Tofana di Mezzo", "Stadio Olimpico del Ghiaccio", "Passo Giau",
        "Monte Cristallo", "Golf Club Cortina", "Parco Naturale delle Dolomiti d'Ampezzo"
    ],
    "Caorle": [
        "Duomo di Santo Stefano", "Santuario della Madonna dell'Angelo", "Spiaggia di Levante",
        "Spiaggia di Ponente", "Scogliera Viva", "Museo Liturgico", "Centro Storico",
        "Luna Park", "Parco del Pescatore", "Porto Peschereccio"
    ],
    "Conegliano": [
        "Castello di Conegliano", "Duomo di Conegliano", "Museo Civico", "Piazza Cima",
        "Teatro Accademia", "Via XX Settembre", "Chiesa di San Pio X", "Parco Mozart",
        "Villa Gera", "Museo degli Alpini"
    ],
    "Adria": [
        "Museo Archeologico Nazionale", "Cattedrale dei Santi Pietro e Paolo", "Teatro Comunale",
        "Piazza Garibaldi", "Chiesa di Santa Maria Assunta della Tomba", "Museo della Cattedrale",
        "Villa Mecenati", "Ponte Castello", "Parco delle Rimembranze", "Palazzo Bocchi"
    ],
    "Este": [
        "Castello di Este", "Roman Amphitheatre ruins", "Duomo di Santa Tecla", "Museo Nazionale Atestino",
        "Piazza Maggiore", "Villa Contarini", "Basilica di Sant'Andrea", "Giardini del Castello",
        "Porta Vecchia", "Chiesa di San Martino"
    ],
    "Cittadella": [
        "City Walls of Cittadella", "Piazza Pierobon", "Torre di Malta", "Palazzo Pretorio",
        "Church of San Donato", "Museo della Città", "Teatro Sociale", "Porta Bassano",
        "Porta Padova", "Palazzo della Loggia"
    ],
    "Arquà Petrarca": [
        "Casa del Petrarca", "Chiesa di Santa Maria Assunta", "Piazza Petrarca",
        "Medieval village center", "Villa Pisani", "Parco della Rimembranza", "Oratorio della Santissima Trinità",
        "Fontana Petrarca", "Museo Petrarchesco", "Monte Ventolone"
    ],
    "Borgo Valsugana": [
        "Castel Telvana", "Ponte Vecchio", "Chiesa di San Rocco", "Museo della Grande Guerra",
        "Parco della Pace", "Palazzo Ceschi", "Via Roma", "Villa Angeli", "Piazza Degasperi", "Museo degli Spaventapasseri"
    ],
    "Feltre": [
        "Castello di Feltre", "Piazza Maggiore", "Cattedrale di San Pietro Apostolo",
        "Palazzo della Magnifica Comunità", "Museo Civico", "Teatro de la Sena", "Porta Imperiale",
        "Chiesa di San Giacomo", "Parco della Birreria", "Villa Pasole"
    ],
    "San Donà di Piave": [
        "Cittadella Medicea", "Piazza Indipendenza", "Church of San Giovanni",
        "Municipal Library", "Villa Ancillotto", "Museo della Bonifica", "Parco Fluviale"
    ],
    "Dolo": [
        "Villa Widmann", "Canale di Dolo", "Ponte di Dolo", "Chiesa di San Pio X",
        "Villa Jacur", "Piazza Cantiere", "Museo del Naviglio"
    ],
    "Monselice": [
        "Rocca di Monselice", "Villa Duodo", "Santuario delle Sette Chiese", "Piazza Mazzini",
        "Museo Rocca", "Castello di Monselice", "Chiesa di San Paolo"
    ],
    "Portogruaro": [
        "Duomo di Portogruaro", "Palazzo degli Asburgo", "Museo Nazionale Concordiese",
        "Piazza della Repubblica", "Chiesa di Sant'Andrea", "Mulini di Sant'Andrea", "Villa Comunale"
    ],
    "San Vito di Cadore": [
        "Chiesa di San Vito", "Museo Ladino Cadorino", "Lago di Antorno",
        "Piani di Pezzè", "Monte Antelao", "Parco NeveSole", "Piazza Medaglie d'Oro"
    ],
    "Campolongo Maggiore": [
        "Villa Manin", "Chiesa di San Giovanni Battista", "Parco delle Risorgive",
        "Villa Venier Contarini", "Piazza Municipio", "Museo della Civiltà Contadina"
    ],
    "Pedavena": [
        "Birrificio Pedavena", "Villa Pasolini dall’Onda", "Piazza Martiri",
        "Chiesa di San Antonio", "Parco della Birreria", "Museo Civico di Pedavena"
    ],
    "Marostica": [
        "Castello Superiore", "Castello Inferiore", "Piazza degli Scacchi", "Museo dei Costumi",
        "Chiesa di Sant'Antonio Abate", "Parco della Rimembranza", "Porta Vicentina"
    ],
    "Valeggio sul Mincio": [
        "Parco Giardino Sigurtà", "Borghetto sul Mincio", "Castello Scaligero",
        "Ponte Visconteo", "Chiesa di San Marco Evangelista", "Museo della Pesca"
    ],
    "Abano Terme": [
        "Parco Urbano Termale", "Museo Villa Bassi Rathgeb", "Duomo di San Lorenzo",
        "Montirone Park", "Piazza del Sole e della Pace", "Chiesa del Sacro Cuore"
    ],
    "Lazise": [
        "Castello Scaligero", "Lungolago Marconi", "Chiesa di San Nicolò", "Piazza Vittorio Emanuele II",
        "Museo del Castello", "Villa Pergolana"
    ],
    "Peschiera del Garda": [
        "Fortezza di Peschiera", "Santuario della Madonna del Frassino", "Museo della Pesca",
        "Porta Verona", "Piazza Ferdinando di Savoia", "Parco Catullo"
    ],
    "Malcesine": [
        "Castello Scaligero di Malcesine", "Funivia Malcesine-Monte Baldo", "Palazzo dei Capitani",
        "Chiesa di Santo Stefano", "Museo del Lago", "Piazza Statuto"
    ],
    "Cavarzere": [
        "Duomo di San Mauro", "Museo Civico", "Piazza Vittorio Emanuele II", "Villa Zennaro",
        "Chiesa di San Bartolomeo", "Parco della Rimembranza"
    ],
    "Noale": [
        "Rocca dei Tempesta", "Duomo di Noale", "Piazza Castello", "Museo Civico di Noale",
        "Chiesa di San Giovanni Battista", "Parco della Bujega"
    ],
    "Mirano": [
        "Villa Morosini XXV Aprile", "Piazza Martiri della Libertà", "Duomo di San Michele Arcangelo",
        "Parco Belvedere", "Museo del Paesaggio", "Villa Erizzo"
    ],
    "Spinea": [
        "Villa Simion", "Parco Nuove Gemme", "Chiesa di San Vito e Modesto", "Piazza Municipio",
        "Museo della Civiltà Contadina", "Villa Loredan"
    ],
    "Mogliano Veneto": [
        "Villa Condulmer", "Piazza Caduti", "Chiesa di Santa Maria Assunta", "Parco Arcobaleno",
        "Museo della Bonifica", "Villa Stucky"
    ],
    "Castelfranco Veneto": [
        "Castello di Castelfranco", "Duomo di Castelfranco", "Teatro Accademico", "Piazza Giorgione",
        "Museo Casa Giorgione", "Villa Revedin Bolasco"
    ],
    "San Bonifacio": [
        "Abbazia di Villanova", "Duomo di San Bonifacio", "Piazza Costituzione", "Museo Civico",
        "Villa Gritti", "Parco della Rimembranza"
    ],
    "Legnago": [
        "Teatro Salieri", "Museo Fioroni", "Duomo di San Martino", "Piazza Garibaldi",
        "Castello di Legnago", "Parco Comunale"
    ],
    "Schio": [
        "Duomo di San Pietro", "Fabbrica Alta", "Parco della Fabbrica Alta", "Museo Civico di Schio",
        "Piazza Alessandro Rossi", "Villa Rossi"
    ],
    "Valdagno": [
        "Villa Valle", "Parco delle Traine", "Roman Villa of Valdagno", "Church of San Clemente",
        "Villa Cerchiari", "Museo Civico di Valdagno"
    ],
    "Vittorio Veneto": [
        "Piazza del Popolo", "Villa Papadopoli", "Duomo di San Tiziano", "Museo della Battaglia",
        "Teatro Da Ponte", "Parco della Vittoria"
    ],
    "Bardolino": [
        "Lake Garda promenade", "Church of San Zeno", "Olive Oil Museum", "Piazza Matteotti",
        "Archaeological Museum", "Parco Baia delle Sirene"
    ],
}



event_types = [
    "Music", "Sport", "Food & Drink", "Arts & Crafts", "Theatre", "Tour", "Workshop",
    "Festival", "Conference", "Exhibition"
]

base_url = "https://example.com/veneto-events/"

def random_date():
    today = datetime.now()
    end_date_limit = datetime(2025, 8, 30)
    # Calculate the difference in days between today and the end date limit
    days_difference = (end_date_limit - today).days

    # Ensure we don't generate dates in the past
    if days_difference < 0:
        return None, None # Or handle as appropriate, e.g., raise an error

    # Generate a random number of days between 0 and the days_difference
    random_days = random.randint(0, days_difference)
    start_date = today + timedelta(days=random_days)

    # Generate random time within the chosen day
    random_hours = random.randint(0, 23)
    random_minutes = random.randint(0, 59)
    start_date = start_date.replace(hour=random_hours, minute=random_minutes, second=0, microsecond=0)

    # Generate a random duration for the event
    duration_hours = random.randint(1, 10)
    end_date = start_date + timedelta(hours=duration_hours)

    # Ensure the end date is not beyond the limit
    if end_date > end_date_limit:
        end_date = end_date_limit # Cap the end date at the limit

    return start_date.isoformat(timespec='minutes'), end_date.isoformat(timespec='minutes')

def generate_random_description(event_type, city, venue):
    description_templates = [
        f"Prepare for an unforgettable {event_type.lower()} experience in the stunning city of {city}, held at the magnificent {venue}. This event promises to be a highlight of the season!",
        f"Dive into the world of {event_type.lower()} at this exciting gathering in {city}. Located at the renowned {venue}, it's an event you won't want to miss.",
        f"Explore the vibrant {event_type.lower()} scene in {city} with this special event at {venue}. Get ready for a day filled with discovery and enjoyment.",
        f"A unique {event_type.lower()} opportunity awaits you in {city}. Join us at the charming {venue} for an event designed to inspire and entertain.",
        f"Immerse yourself in the rich culture of {city} with this engaging {event_type.lower()} event at the iconic {venue}. It's the perfect way to spend your time.",
        f"Seeking adventure in {city}? Look no further than this captivating {event_type.lower()} event at {venue}. Fun and excitement are guaranteed!",
        f"Connect with fellow enthusiasts at this lively {event_type.lower()} event in {city}, taking place at the welcoming {venue}. Share your passion and make new friends.",
        f"Unwind and enjoy a delightful {event_type.lower()} experience in {city} at the picturesque {venue}. Relax and take in the atmosphere.",
        f"Expand your horizons with this insightful {event_type.lower()} event in {city}, hosted at the distinguished {venue}. Learn something new and be inspired.",
        f"Step into a world of wonder at this extraordinary {event_type.lower()} event in {city}, held at the historic {venue}. Prepare to be amazed!"
    ]
    return random.choice(description_templates).format(event_type=event_type.lower(), city=city, venue=venue)


events = []

for i in range(1, 500): # Generate 500 events Changed range to 10001 to generate 10000 events
    city = random.choice(list(locations.keys()))
    venue = random.choice(locations[city])
    event_type = random.choice(event_types)
    start, end = random_date()

    # Only add event if a valid date range was generated
    if start and end:
        event = {
            "id": str(i),
            "title": f"{city} {event_type} Event #{i}",
            "type": event_type,
            "category": event_type, # Added category field
            "description": generate_random_description(event_type, city, venue),
            "city": city,
            "location": {
                "venue": venue,
                "address": f"{venue}, {city}, Veneto"
            },
            "start_date": start,
            "end_date": end,
            "url": f"{base_url}{i}"
        }
        events.append(event)

output = {
    "events": events
}

# Save to JSON file
with open("veneto_events.json", "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print(f"Generated veneto_events.json with {len(events)} events")
# Out:
# Generated veneto_events.json with 499 events

# %% [markdown]
# #### Geocoding Veneto Events 🌍
#
# Geocode synthetic event data for Veneto using the OpenStreetMap Nominatim API.
#
# **Workflow:**
# - Load events from `veneto_events.json`
# - Clean addresses (venue, city, region, country)
# - Geocode each event (with fallback strategies)
# - Rate limit to respect API usage
# - Add coordinates to each event
# - Save results to `veneto_events_geocoded_structured.json`

# %%
import json
import time
import requests

def geocode_structured(venue, city, region="Veneto", country="Italy"):
    base_url = "https://nominatim.openstreetmap.org/search"
    headers = {'User-Agent': 'convert_to_geo/1.0'}

    params_list = [
        {'street': venue, 'city': city, 'state': region, 'country': country, 'format': 'json', 'limit': 1},
        {'city': city, 'state': region, 'country': country, 'format': 'json', 'limit': 1},
        {'street': venue, 'city': city, 'country': country, 'format': 'json', 'limit': 1},
        {'street': venue, 'state': region, 'country': country, 'format': 'json', 'limit': 1}
    ]

    for params in params_list:
        response = requests.get(base_url, params=params, headers=headers)
        if response.status_code != 200:
            continue
        data = response.json()
        if data:
            # Fix: Access lon from the first element of the list as well
            return float(data[0]['lat']), float(data[0]['lon'])
        time.sleep(1)  # Respect rate limit

    return None, None

def clean_address(event):
    venue = event.get('location', {}).get('venue', '').strip()
    city = event.get('city', '').strip()
    region = "Veneto"
    country = "Italy"

    parts = []

    def add_unique(part):
        if part and part.lower() not in [p.lower() for p in parts]:
            parts.append(part)

    add_unique(venue)
    add_unique(city)
    add_unique(region)
    add_unique(country)

    return ', '.join(parts)

# Load events
with open('veneto_events.json', 'r', encoding='utf-8') as f:
    events_data = json.load(f)

# Geocode and add lat/lon to each event
for idx, event in enumerate(events_data['events'], 1):
    venue = event.get('location', {}).get('venue', '').strip()
    city = event.get('city', '').strip()
    if venue and city:
        lat, lon = geocode_structured(venue, city)
    else:
        lat, lon = None, None
    event['location']['latitude'] = lat
    event['location']['longitude'] = lon
    print(f"Geocoded n. {idx}: {venue}, {city} -> {lat}, {lon}")

# Save results with geocodes
with open('veneto_events_geocoded_structured.json', 'w', encoding='utf-8') as f:
    json.dump(events_data, f, ensure_ascii=False, indent=2)

print("Geocoding complete and saved to veneto_events_geocoded_structured.json")
# Out:
# Geocoded n. 1: Piazza del Popolo, Vittorio Veneto -> 45.9897336, 12.295648
# Geocoded n. 2: Parco Naturale delle Dolomiti d'Ampezzo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 3: Museo Civico di Valdagno, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 4: Castello Scaligero di Malcesine, Malcesine -> 45.7643442, 10.8100598
# Geocoded n. 5: Accademia dei Concordi, Rovigo -> 45.0709431, 11.7903377
# Geocoded n. 6: Parco Zoo Punta Verde, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 7: Parco delle Risorgive, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 8: Duomo di Santa Tecla, Este -> 45.2299866, 11.6536381
# Geocoded n. 9: Palazzo Ducale, Venice -> 45.4371908, 12.3345898
# Geocoded n. 10: Piazza Statuto, Malcesine -> 45.7631123, 10.8080612
# Geocoded n. 11: Rocca di Asolo, Asolo -> 45.8053196, 11.9176075
# Geocoded n. 12: Parco delle Rimembranze, Adria -> 45.0531228, 12.0572
# Geocoded n. 13: Campo Santa Margherita, Venice -> 45.4342932, 12.323715
# Geocoded n. 14: Duomo di Conegliano, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 15: Castello Inferiore, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 16: Duomo di San Martino, Legnago -> 45.192498, 11.3111274
# Geocoded n. 17: Fabbrica Alta, Schio -> 45.7113511, 11.3553593
# Geocoded n. 18: Piazza Vittorio Emanuele II, Lazise -> 45.5052855, 10.7330286
# Geocoded n. 19: Chiesa di Sant'Andrea, Portogruaro -> 45.775598, 12.8374571
# Geocoded n. 20: Campo Santa Margherita, Venice -> 45.4342932, 12.323715
# Geocoded n. 21: Palazzo Zabarella, Padua -> 45.4077172, 11.8734455
# Geocoded n. 22: Museo Lapidario Maffeiano, Verona -> 45.4381803, 10.9913534
# Geocoded n. 23: Museo della Pesca, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 24: Piazza Vittorio Emanuele II, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 25: Lungolago Marconi, Lazise -> 45.5074454, 10.731187
# Geocoded n. 26: Passo Giau, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 27: Medieval village center, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 28: Parco Nuove Gemme, Spinea -> 45.4911604, 12.165018
# Geocoded n. 29: Museo Civico di Pedavena, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 30: Piazza Martiri della Libertà, Mirano -> 45.4931149, 12.1094823
# Geocoded n. 31: Duomo di Conegliano, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 32: Villa Venier Contarini, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 33: Palazzo Ducale, Venice -> 45.4371908, 12.3345898
# Geocoded n. 34: Museo della Bonifica, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 35: Parco Nuove Gemme, Spinea -> 45.4911604, 12.165018
# Geocoded n. 36: Church of Santa Caterina, Asolo -> 45.8007265, 11.9142444
# Geocoded n. 37: Parco Belvedere, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 38: Chiesa di San Paolo, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 39: Chiesa di Sant'Antonio Abate, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 40: Chiesa di San Giovanni Battista, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 41: Villa La Rotonda, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 42: Parco delle Traine, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 43: Villa Maser, Asolo -> 45.8007265, 11.9142444
# Geocoded n. 44: Museo dei Costumi, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 45: Teatro Salieri, Legnago -> 45.1914252, 11.3074076
# Geocoded n. 46: Duomo di San Tiziano, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 47: Centro Culturale Candiani, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 48: Villa Widmann, Dolo -> 45.4234356, 12.0743252
# Geocoded n. 49: Palazzo Bocchi, Adria -> 45.0531228, 12.0572
# Geocoded n. 50: Isola di Pellestrina, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 51: Parco Comunale, Legnago -> 45.192498, 11.3111274
# Geocoded n. 52: Porta Vicentina, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 53: Museo della Città, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 54: Lake Garda promenade, Bardolino -> 45.5475595, 10.7242145
# Geocoded n. 55: Monte Antelao, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 56: Laguna del Mort, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 57: Parco della Vittoria, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 58: Parco Catullo, Peschiera del Garda -> 45.4397171, 10.6940451
# Geocoded n. 59: Parco Urbano Termale, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 60: Museo di Santa Caterina, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 61: Lago di Pianozes, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 62: Museo Fioroni, Legnago -> 45.192498, 11.3111274
# Geocoded n. 63: Piazza Municipio, Spinea -> 45.4915047, 12.1647504
# Geocoded n. 64: Duomo di San Michele Arcangelo, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 65: Villa Revedin Bolasco, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 66: Cattedrale di Santa Maria Assunta, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 67: Church of the Eremitani, Padua -> 45.4077172, 11.8734455
# Geocoded n. 68: Museum of Castelvecchio, Verona -> 45.4384958, 10.9924122
# Geocoded n. 69: Borghetto sul Mincio, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 70: Museo Naturalistico Archeologico, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 71: Ponte Vigo, Chioggia -> 45.2231644, 12.2811481
# Geocoded n. 72: Santuario della Madonna dell'Angelo, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 73: Rocca di Asolo, Asolo -> 45.8046333, 11.9189322
# Geocoded n. 74: Duomo di San Pietro, Schio -> 45.7113511, 11.3553593
# Geocoded n. 75: Parco Naturale delle Dolomiti d'Ampezzo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 76: Parco delle Risorgive, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 77: Church of San Zeno, Bardolino -> 45.5475595, 10.7242145
# Geocoded n. 78: Tofana di Mezzo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 79: Palazzo della Ragione, Padua -> 45.4077172, 11.8734455
# Geocoded n. 80: Palazzo Liviano, Padua -> 45.407986, 11.8714491
# Geocoded n. 81: Chiesa del Sacro Cuore, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 82: Parco della Rimembranza, San Bonifacio -> 45.3956425, 11.2700817
# Geocoded n. 83: Ponte Vecchio, Borgo Valsugana -> 45.7674809, 11.7317415
# Geocoded n. 84: Piazza Degasperi, Borgo Valsugana -> None, None
# Geocoded n. 85: Laguna del Mort, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 86: Golf Club Cortina, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 87: Chiesa di San Giovanni Battista, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 88: Teatro Salieri, Legnago -> 45.1914252, 11.3074076
# Geocoded n. 89: Laguna del Mort, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 90: Luna Park, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 91: Duomo di Santa Tecla, Este -> 45.2299866, 11.6536381
# Geocoded n. 92: Palazzo Bomben, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 93: Castello di Castelfranco, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 94: Church of San Zeno, Bardolino -> 45.5475595, 10.7242145
# Geocoded n. 95: Piazza Alessandro Rossi, Schio -> 45.7143939, 11.3590481
# Geocoded n. 96: Museo Civico, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 97: Sea Life Aquarium, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 98: Piazza Petrarca, Arquà Petrarca -> 45.2692493, 11.7194842
# Geocoded n. 99: Venetian Arsenal, Venice -> 45.4371908, 12.3345898
# Geocoded n. 100: Museo Civico, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 101: Museo Liturgico, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 102: Passo Giau, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 103: Museo dei Costumi, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 104: Piazza del Popolo, Vittorio Veneto -> 45.9897336, 12.295648
# Geocoded n. 105: Teatro Toniolo, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 106: Chiesa di San Vito e Modesto, Spinea -> 45.4911604, 12.165018
# Geocoded n. 107: Villa Papadopoli, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 108: Parco della Rimembranza, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 109: Castello Scaligero, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 110: Museo Civico di Noale, Noale -> 45.550156, 12.0720437
# Geocoded n. 111: Villa Rossi, Schio -> 45.7113511, 11.3553593
# Geocoded n. 112: Piazza delle Erbe, Verona -> 45.4430622, 10.9972338
# Geocoded n. 113: Villa Mecenati, Adria -> 45.0531228, 12.0572
# Geocoded n. 114: Museo della Pesca, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 115: Villa Papadopoli, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 116: Centro Culturale Candiani, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 117: Villa Venier Contarini, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 118: Museo Liturgico, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 119: Funivia Malcesine-Monte Baldo, Malcesine -> 45.7661246, 10.8132676
# Geocoded n. 120: Museo della Pesca, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 121: Parco Nuove Gemme, Spinea -> 45.4911604, 12.165018
# Geocoded n. 122: Piazza Matteotti, Bardolino -> 45.5471201, 10.7203132
# Geocoded n. 123: Museo Civico di Jesolo, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 124: Porta Imperiale, Feltre -> 46.0163755, 11.9062541
# Geocoded n. 125: Piazza Matteotti, Bardolino -> 45.5471201, 10.7203132
# Geocoded n. 126: Museo Civico, Belluno -> 46.1375185, 12.2181711
# Geocoded n. 127: Museo Civico di Jesolo, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 128: Museo della Pesca, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 129: Chiesa di Santa Maria Assunta, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 130: Museo d'Arte Moderna Mario Rimoldi, Cortina d'Ampezzo -> 46.5369628, 12.1372128
# Geocoded n. 131: Museo Nazionale Concordiese, Portogruaro -> 45.775345, 12.835497
# Geocoded n. 132: Villa Manin, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 133: Museo Naturalistico Archeologico, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 134: Museo Lapidario Maffeiano, Verona -> 45.4381803, 10.9913534
# Geocoded n. 135: Museo Naturalistico Archeologico, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 136: Church of San Lorenzo, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 137: Museo Bottacin, Padua -> 45.4114324, 11.8781539
# Geocoded n. 138: Fortezza di Peschiera, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 139: Parco Giardino Sigurtà, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 140: Parco Arcobaleno, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 141: Villa Condulmer, Mogliano Veneto -> 45.5776574, 12.2660802
# Geocoded n. 142: Parco della Fabbrica Alta, Schio -> 45.7113511, 11.3553593
# Geocoded n. 143: Museo degli Alpini, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 144: Montirone Park, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 145: Chiesa di San Domenico, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 146: Chiesa di San Giovanni Battista, Bassano del Grappa -> 45.7669109, 11.7343469
# Geocoded n. 147: Chiesa del Sacro Cuore, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 148: Castello Scaligero, Lazise -> 45.5052005, 10.7330245
# Geocoded n. 149: Monte Cristallo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 150: Duomo di San Martino, Legnago -> 45.192498, 11.3111274
# Geocoded n. 151: Piazza Municipio, Spinea -> 45.4915047, 12.1647504
# Geocoded n. 152: Piazza Mazzini, Monselice -> 45.2415369, 11.7509116
# Geocoded n. 153: Museo della Battaglia, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 154: Teatro Accademia, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 155: Piazza dei Signori, Verona -> 45.4434665, 10.9980787
# Geocoded n. 156: Museo del Paesaggio, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 157: Parco della Vittoria, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 158: Roman Amphitheatre ruins, Este -> 45.2240069, 11.659796
# Geocoded n. 159: Porta San Tommaso, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 160: Parco della Rimembranza, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 161: Duomo di San Michele Arcangelo, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 162: Museo della Padova Ebraica, Padua -> 45.4060426, 11.8759223
# Geocoded n. 163: Piazza Petrarca, Arquà Petrarca -> 45.26913, 11.719406
# Geocoded n. 164: Villa Querini, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 165: Castello degli Ezzelini, Bassano del Grappa -> 45.7669109, 11.7343469
# Geocoded n. 166: Piazza Vittorio Emanuele II, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 167: Basilica di Sant'Andrea, Este -> 45.2240069, 11.659796
# Geocoded n. 168: Museo della Pesca, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 169: Villa Condulmer, Mogliano Veneto -> 45.5776574, 12.2660802
# Geocoded n. 170: Parco Comunale, Legnago -> 45.192498, 11.3111274
# Geocoded n. 171: Museo dei Grandi Fiumi, Rovigo -> 45.0698166, 11.78882
# Geocoded n. 172: Piazza Martiri della Libertà, Mirano -> 45.4928792, 12.1095192
# Geocoded n. 173: Palazzo Grimani, Venice -> 45.4371908, 12.3345898
# Geocoded n. 174: Basilica di Sant'Andrea, Este -> 45.2240069, 11.659796
# Geocoded n. 175: Museo Nazionale Concordiese, Portogruaro -> 45.775345, 12.835497
# Geocoded n. 176: Church of San Lorenzo, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 177: Palazzo degli Asburgo, Portogruaro -> 45.775598, 12.8374571
# Geocoded n. 178: Castello di Conegliano, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 179: Museo del Paesaggio, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 180: Chiesa di San Giovanni Battista, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 181: Museo Fioroni, Legnago -> 45.192498, 11.3111274
# Geocoded n. 182: Montirone Park, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 183: Parco NeveSole, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 184: Palazzo Barbieri, Verona -> 45.4384958, 10.9924122
# Geocoded n. 185: Chiesa di Santa Maria Assunta, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 186: Forte Marghera, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 187: Villa Gera, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 188: Cattedrale dei Santi Pietro e Paolo, Adria -> 45.0531228, 12.0572
# Geocoded n. 189: Ponte di Dolo, Dolo -> 45.4221058, 12.0777774
# Geocoded n. 190: Piazza Indipendenza, San Donà di Piave -> 45.6294057, 12.5642475
# Geocoded n. 191: Villa Querini, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 192: Villa Cerchiari, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 193: Palazzo della Loggia, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 194: Rialto Bridge, Venice -> 45.4380688, 12.3356548
# Geocoded n. 195: Museo dei Grandi Fiumi, Rovigo -> 45.0698166, 11.78882
# Geocoded n. 196: Parco della Vittoria, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 197: Museo della Bonifica, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 198: Verona Exhibition Center, Verona -> 45.4384958, 10.9924122
# Geocoded n. 199: Ponte degli Alpini, Bassano del Grappa -> 45.7674953, 11.7311664
# Geocoded n. 200: Villa Rossi, Schio -> 45.7113511, 11.3553593
# Geocoded n. 201: Basilica Palladiana, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 202: Duomo di Castelfranco, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 203: Monte Antelao, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 204: Parco Naturale delle Dolomiti d'Ampezzo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 205: Museo della Civiltà Contadina, Spinea -> 45.4911604, 12.165018
# Geocoded n. 206: Chiesa di Sant'Antonio Abate, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 207: Church of the Eremitani, Padua -> 45.4077172, 11.8734455
# Geocoded n. 208: Porta Vecchia, Este -> 45.2240069, 11.659796
# Geocoded n. 209: Sottomarina Beach, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 210: Museo della Pesca, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 211: Museo Antoniano, Padua -> 45.4077172, 11.8734455
# Geocoded n. 212: Lago di Pianozes, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 213: Church of San Lorenzo, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 214: Villa Stucky, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 215: Museo Nazionale Concordiese, Portogruaro -> 45.775345, 12.835497
# Geocoded n. 216: Roman Theatre, Verona -> 45.4384958, 10.9924122
# Geocoded n. 217: Castello degli Ezzelini, Bassano del Grappa -> 45.7669109, 11.7343469
# Geocoded n. 218: Canale di Dolo, Dolo -> 45.4234356, 12.0743252
# Geocoded n. 219: Palazzo Maffei, Verona -> 45.4384958, 10.9924122
# Geocoded n. 220: Duomo di Noale, Noale -> 45.550156, 12.0720437
# Geocoded n. 221: Parco Naturale delle Dolomiti d'Ampezzo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 222: Villa Zennaro, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 223: Parco della Rimembranza, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 224: Castello Superiore, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 225: Chiesa di Santa Maria Assunta, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 226: Basilica Minore dei Santi Filippo e Giacomo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 227: Villa Comunale, Portogruaro -> 45.775598, 12.8374571
# Geocoded n. 228: Villa Valle, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 229: Villa Stucky, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 230: Aqualandia Waterpark, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 231: Villa Cerchiari, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 232: Duomo di Castelfranco, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 233: Villa Widmann, Dolo -> 45.4234356, 12.0743252
# Geocoded n. 234: Parco Catullo, Peschiera del Garda -> 45.4396945, 10.6941419
# Geocoded n. 235: Chiesa di San Antonio, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 236: Parco Urbano Termale, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 237: Villa Zennaro, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 238: Lago di Antorno, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 239: Piazza Brescia, Jesolo -> 45.5019997, 12.6329125
# Geocoded n. 240: Castello Scaligero di Malcesine, Malcesine -> 45.7643442, 10.8100598
# Geocoded n. 241: Via Roma, Borgo Valsugana -> 46.0528703, 11.4517093
# Geocoded n. 242: Giardini del Castello, Este -> 45.2240069, 11.659796
# Geocoded n. 243: Ponte Scaligero, Verona -> 45.4384958, 10.9924122
# Geocoded n. 244: Cittadella Medicea, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 245: Borghetto sul Mincio, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 246: Castello di Feltre, Feltre -> 46.0163755, 11.9062541
# Geocoded n. 247: Museo Civico, Asolo -> 45.8007265, 11.9142444
# Geocoded n. 248: Santuario delle Sette Chiese, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 249: Museo della Grande Guerra, Borgo Valsugana -> None, None
# Geocoded n. 250: Accademia dei Concordi, Rovigo -> 45.0709431, 11.7903377
# Geocoded n. 251: Torre dell'Orologio, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 252: Corso del Popolo, Chioggia -> 45.2187118, 12.278491
# Geocoded n. 253: Duomo di San Tiziano, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 254: Piazza Garibaldi, Asolo -> 45.8022047, 11.9134666
# Geocoded n. 255: Duomo di San Pietro, Schio -> 45.7113511, 11.3553593
# Geocoded n. 256: Fontane di Treviso, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 257: Parco delle Rimembranze, Adria -> 45.0531228, 12.0572
# Geocoded n. 258: Villa Pergolana, Lazise -> 45.5052005, 10.7330245
# Geocoded n. 259: Museo Ladino Cadorino, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 260: Laguna del Lusenzo, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 261: Piazza dei Signori, Vicenza -> 45.5473193, 11.5465538
# Geocoded n. 262: Museo Civico, Bassano del Grappa -> 45.7669109, 11.7343469
# Geocoded n. 263: Mulini di Sant'Andrea, Portogruaro -> 45.775598, 12.8374571
# Geocoded n. 264: Piazza Caduti, Mogliano Veneto -> 45.5611317, 12.2363049
# Geocoded n. 265: Birrificio Pedavena, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 266: Museo Civico di Pedavena, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 267: Porta Vicentina, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 268: Chiesa del Sacro Cuore, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 269: Villa Papadopoli, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 270: Chiesa di San Marco Evangelista, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 271: Piazza Mazzini, Monselice -> 45.2415369, 11.7509116
# Geocoded n. 272: Parco Mozart, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 273: Teatro de la Sena, Feltre -> 46.0163755, 11.9062541
# Geocoded n. 274: Funivia Faloria, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 275: Via Roma, Borgo Valsugana -> 46.0528703, 11.4517093
# Geocoded n. 276: Chiesa di San Pio X, Dolo -> 45.4234356, 12.0743252
# Geocoded n. 277: Olive Oil Museum, Bardolino -> 45.5238629, 10.7289606
# Geocoded n. 278: Parco Zoo Punta Verde, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 279: Parco della Pace, Borgo Valsugana -> 46.0545204, 11.4609416
# Geocoded n. 280: Piazza Giorgione, Castelfranco Veneto -> 45.6729185, 11.925768
# Geocoded n. 281: Piazza dei Frutti, Padua -> 45.407648, 11.8753473
# Geocoded n. 282: Museo Nazionale Atestino, Este -> 45.2296094, 11.6563462
# Geocoded n. 283: Villa Barbaro, Asolo -> 45.8007265, 11.9142444
# Geocoded n. 284: Villa Ancillotto, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 285: Museo della Padova Ebraica, Padua -> 45.4060426, 11.8759223
# Geocoded n. 286: Castello di Legnago, Legnago -> 45.192498, 11.3111274
# Geocoded n. 287: Museo Rocca, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 288: Duomo di San Mauro, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 289: Villa Jacur, Dolo -> 45.4234356, 12.0743252
# Geocoded n. 290: Museo del Lago, Malcesine -> 45.7643442, 10.8100598
# Geocoded n. 291: Teatro Da Ponte, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 292: Duomo di San Bonifacio, San Bonifacio -> 45.3956425, 11.2700817
# Geocoded n. 293: Birrificio Pedavena, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 294: Ponte di Dolo, Dolo -> 45.4221058, 12.0777774
# Geocoded n. 295: Villa Pasole, Feltre -> 46.0412156, 11.9350544
# Geocoded n. 296: Parco della Rimembranza, San Bonifacio -> 45.3956425, 11.2700817
# Geocoded n. 297: Santa Anastasia Church, Verona -> 45.4384958, 10.9924122
# Geocoded n. 298: Roman Villa of Valdagno, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 299: Chiesa di San Nicolò, Lazise -> 45.5052005, 10.7330245
# Geocoded n. 300: Cattedrale dei Santi Pietro e Paolo, Adria -> 45.0531228, 12.0572
# Geocoded n. 301: Teatro Sociale, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 302: Lake Garda promenade, Bardolino -> 45.5475595, 10.7242145
# Geocoded n. 303: Museo Rocca, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 304: Castello Scaligero, Lazise -> 45.5052005, 10.7330245
# Geocoded n. 305: Piazza Mazzini, Monselice -> 45.2415369, 11.7509116
# Geocoded n. 306: Oratorio della Santissima Trinità, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 307: Museo della Civiltà Contadina, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 308: Villa Cerchiari, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 309: Castello Inferiore, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 310: Duomo di San Michele Arcangelo, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 311: Ghetto Nuovo Synagogue, Venice -> 45.4371908, 12.3345898
# Geocoded n. 312: Chiesa di San Bartolomeo, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 313: Villa Pisani, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 314: Castello di Castelfranco, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 315: Duomo di Santa Tecla, Este -> 45.2299866, 11.6536381
# Geocoded n. 316: Parco della Bujega, Noale -> 45.550156, 12.0720437
# Geocoded n. 317: Parco delle Rimembranze, Adria -> 45.0531228, 12.0572
# Geocoded n. 318: Villa Valmarana ai Nani, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 319: Church of San Donato, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 320: Torre di Malta, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 321: Museo Civico, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 322: Villa Rossi, Schio -> 45.7113511, 11.3553593
# Geocoded n. 323: Castello di Castelfranco, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 324: Spiaggia di Levante, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 325: Duomo di San Pietro, Schio -> 45.7113511, 11.3553593
# Geocoded n. 326: Parco della Rimembranza, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 327: Porta Vecchia, Este -> 45.2240069, 11.659796
# Geocoded n. 328: Teatro Remondini, Bassano del Grappa -> 45.7669109, 11.7343469
# Geocoded n. 329: Villa Manin, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 330: Fontana Petrarca, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 331: Museo dei Costumi, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 332: Duomo di San Pietro, Schio -> 45.7113511, 11.3553593
# Geocoded n. 333: Roman Amphitheatre ruins, Este -> 45.2240069, 11.659796
# Geocoded n. 334: Piazza Pierobon, Cittadella -> 45.6486113, 11.7839469
# Geocoded n. 335: Medieval village center, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 336: Parco della Bujega, Noale -> 45.550156, 12.0720437
# Geocoded n. 337: Teatro Accademico, Castelfranco Veneto -> 45.671139, 11.9265624
# Geocoded n. 338: Museo Liturgico, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 339: Museo Naturalistico Archeologico, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 340: Castello Scaligero, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 341: Museo Antoniano, Padua -> 45.4077172, 11.8734455
# Geocoded n. 342: Villa Venier Contarini, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 343: Piazza delle Erbe, Verona -> 45.4431431, 10.9973735
# Geocoded n. 344: Casa del Petrarca, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 345: Teatro Da Ponte, Vittorio Veneto -> 45.9897826, 12.2957596
# Geocoded n. 346: Orto Botanico, Padua -> 45.4004575, 11.8798246
# Geocoded n. 347: Lago di Antorno, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 348: Museo Civico della Laguna Sud, Chioggia -> 45.2152733, 12.2776619
# Geocoded n. 349: Villa Cerchiari, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 350: Municipal Library, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 351: Duomo di Conegliano, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 352: Montirone Park, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 353: Castello della Regina, Asolo -> 45.8007265, 11.9142444
# Geocoded n. 354: Piazza Maggiore, Este -> 45.2280575, 11.6560993
# Geocoded n. 355: Piazza Costituzione, San Bonifacio -> 45.3953901, 11.2693904
# Geocoded n. 356: Rotonda di Vicenza, Vicenza -> 45.5307585, 11.5539637
# Geocoded n. 357: Chiesa di San Giovanni Battista, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 358: Fontane di Treviso, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 359: Municipal Library, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 360: Museo della Cattedrale, Adria -> 45.0531228, 12.0572
# Geocoded n. 361: Museo della Pesca, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 362: Ponte Scaligero, Verona -> 45.4384958, 10.9924122
# Geocoded n. 363: Museo Rocca, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 364: Castello Scaligero di Malcesine, Malcesine -> 45.7643442, 10.8100598
# Geocoded n. 365: Villa Erizzo, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 366: Villa Erizzo, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 367: Mulini di Sant'Andrea, Portogruaro -> 45.775598, 12.8374571
# Geocoded n. 368: Fontana Petrarca, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 369: Golf Club Cortina, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 370: Parco Nazionale Dolomiti Bellunesi, Belluno -> 46.0224949, 11.8993517
# Geocoded n. 371: Piazza Garibaldi, Asolo -> 45.8022047, 11.9134666
# Geocoded n. 372: Museo della Bonifica, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 373: Piazza Municipio, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 374: Church of San Zaccaria, Venice -> 45.4371908, 12.3345898
# Geocoded n. 375: Chiesa di San Antonio, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 376: Villa Pasolini dall’Onda, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 377: Monte Antelao, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 378: Porta Padova, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 379: Parco Mozart, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 380: Scogliera Viva, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 381: Municipal Library, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 382: City Walls of Cittadella, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 383: Villa Zennaro, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 384: Centro Storico, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 385: Museo della Bonifica, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 386: Fontane di Treviso, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 387: Rocca dei Tempesta, Noale -> 45.550156, 12.0720437
# Geocoded n. 388: Scala Contarini del Bovolo, Venice -> 45.4371908, 12.3345898
# Geocoded n. 389: Duomo di San Pietro, Schio -> 45.7113511, 11.3553593
# Geocoded n. 390: Palazzo Bonin Longare, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 391: Villa Simion, Spinea -> 45.4926514, 12.1613575
# Geocoded n. 392: Parco NeveSole, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 393: Cattedrale dei Santi Pietro e Paolo, Adria -> 45.0531228, 12.0572
# Geocoded n. 394: Fontane di Treviso, Treviso -> 45.6658505, 12.2455414
# Geocoded n. 395: Piazza Municipio, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 396: Roman Amphitheatre ruins, Este -> 45.2240069, 11.659796
# Geocoded n. 397: Piazza Petrarca, Arquà Petrarca -> 45.26913, 11.719406
# Geocoded n. 398: Santuario delle Sette Chiese, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 399: Piazza della Repubblica, Portogruaro -> 45.7755764, 12.8376743
# Geocoded n. 400: Parco delle Rimembranze, Adria -> 45.0531228, 12.0572
# Geocoded n. 401: Castello Superiore, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 402: Museo Villa Bassi Rathgeb, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 403: Piazza Caduti, Mogliano Veneto -> 45.5611317, 12.2363049
# Geocoded n. 404: Chiesa di San Bartolomeo, Cavarzere -> 45.1360987, 12.0812854
# Geocoded n. 405: Tropicarium Park, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 406: Basilica di Sant'Andrea, Este -> 45.2240069, 11.659796
# Geocoded n. 407: Villa Duodo, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 408: Villa Cerchiari, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 409: Palazzo Thiene, Vicenza -> 45.5485908, 11.5457432
# Geocoded n. 410: Golf Club Cortina, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 411: Duomo di San Michele Arcangelo, Mirano -> 45.4927695, 12.1098768
# Geocoded n. 412: Parco della Bujega, Noale -> 45.550156, 12.0720437
# Geocoded n. 413: Lago di Pianozes, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 414: Museo Diocesano, Padua -> 45.4077172, 11.8734455
# Geocoded n. 415: Museo Petrarchesco, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 416: Piazza Alessandro Rossi, Schio -> 45.7143939, 11.3590481
# Geocoded n. 417: Archaeological Museum, Bardolino -> 45.5475595, 10.7242145
# Geocoded n. 418: Spiaggia di Levante, Caorle -> 45.5979147, 12.8876282
# Geocoded n. 419: Museo Rocca, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 420: Chiesa di San Martino, Este -> 45.2240069, 11.659796
# Geocoded n. 421: Museo della Civiltà Contadina, Spinea -> 45.4911604, 12.165018
# Geocoded n. 422: Museo del Castello, Lazise -> 45.5052005, 10.7330245
# Geocoded n. 423: Piani di Pezzè, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 424: Palazzo Bocchi, Adria -> 45.0531228, 12.0572
# Geocoded n. 425: Duomo di San Bonifacio, San Bonifacio -> 45.3956425, 11.2700817
# Geocoded n. 426: Chiesa di San Pio X, Conegliano -> 45.8862172, 12.2977566
# Geocoded n. 427: Palazzo della Magnifica Comunità, Feltre -> 46.0163755, 11.9062541
# Geocoded n. 428: Piazza Municipio, Spinea -> 45.4915047, 12.1647504
# Geocoded n. 429: Villa Loredan, Spinea -> 45.4911604, 12.165018
# Geocoded n. 430: Isola di Burano, Venice -> 45.4371908, 12.3345898
# Geocoded n. 431: Ponte della Vittoria, Belluno -> 46.1343674, 12.2188234
# Geocoded n. 432: Parco Fluviale, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 433: Villa Pasolini dall’Onda, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 434: Ponte Vigo, Chioggia -> 45.2231851, 12.2810534
# Geocoded n. 435: Museo del Lago, Malcesine -> 45.7643442, 10.8100598
# Geocoded n. 436: Museo Villa Bassi Rathgeb, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 437: Parco Arcobaleno, Mogliano Veneto -> 45.5612886, 12.2376973
# Geocoded n. 438: Church of San Zeno, Bardolino -> 45.5475595, 10.7242145
# Geocoded n. 439: City Walls of Cittadella, Cittadella -> 45.6487941, 11.7835801
# Geocoded n. 440: Piazza Maggiore, Este -> 45.2280476, 11.6563777
# Geocoded n. 441: Oratorio della Santissima Trinità, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 442: Chiesa di San Vito, San Vito di Cadore -> 46.458966, 12.2057415
# Geocoded n. 443: Piazza del Sole e della Pace, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 444: Torre dell'Orologio, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 445: Scrovegni Chapel, Padua -> 45.4077172, 11.8734455
# Geocoded n. 446: Porta Verona, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 447: Museo dei Costumi, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 448: Villa Manin, Campolongo Maggiore -> 45.3305355, 12.0483135
# Geocoded n. 449: Duomo di San Pietro, Schio -> 45.7113511, 11.3553593
# Geocoded n. 450: Chiesa di Santa Maria Assunta, Arquà Petrarca -> 45.2700441, 11.7165149
# Geocoded n. 451: Pineta Beach, Jesolo -> 45.5367094, 12.6383337
# Geocoded n. 452: Parco Nuove Gemme, Spinea -> 45.4911604, 12.165018
# Geocoded n. 453: Rocca dei Tempesta, Noale -> 45.550156, 12.0720437
# Geocoded n. 454: Cattedrale di Padova, Padua -> 45.4077172, 11.8734455
# Geocoded n. 455: Museo Civico, Asolo -> 45.8007265, 11.9142444
# Geocoded n. 456: Piazza Castello, Noale -> 45.5505965, 12.0701089
# Geocoded n. 457: Teatro de la Sena, Feltre -> 46.0163755, 11.9062541
# Geocoded n. 458: Piazza degli Scacchi, Marostica -> 45.745514, 11.6552998
# Geocoded n. 459: Basilica di Sant'Andrea, Este -> 45.2240069, 11.659796
# Geocoded n. 460: Parco delle Traine, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 461: Museo Nazionale Concordiese, Portogruaro -> 45.775345, 12.835497
# Geocoded n. 462: Parco della Birreria, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 463: Municipal Library, San Donà di Piave -> 45.6294811, 12.5641057
# Geocoded n. 464: Murano Glass Museum, Venice -> 45.4371908, 12.3345898
# Geocoded n. 465: Parco Naturale delle Dolomiti d'Ampezzo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 466: Chiesa di Sant'Antonio Abate, Marostica -> 45.7453924, 11.6568938
# Geocoded n. 467: Galleria Matteotti, Mestre -> 45.4930827, 12.239705
# Geocoded n. 468: Cattedrale di Santa Maria Assunta, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 469: Palazzo Liviano, Padua -> 45.407986, 11.8714491
# Geocoded n. 470: Piazza Martiri, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 471: Palazzo dei Capitani, Malcesine -> 45.7642401, 10.8070956
# Geocoded n. 472: Chiesa di San Antonio, Pedavena -> 46.0396242, 11.8804327
# Geocoded n. 473: Palazzo Grimani, Venice -> 45.4371908, 12.3345898
# Geocoded n. 474: Museo Rocca, Monselice -> 45.2417684, 11.7508534
# Geocoded n. 475: Duomo di San Lorenzo, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 476: Castello di Monselice, Monselice -> 45.2447718, 11.7532391
# Geocoded n. 477: Parco della Birreria, Feltre -> 46.0163755, 11.9062541
# Geocoded n. 478: Museo Naturalistico Archeologico, Vicenza -> 45.5488306, 11.5478825
# Geocoded n. 479: Basilica di Sant'Antonio, Padua -> 45.4014584, 11.8808472
# Geocoded n. 480: Lido di Venezia, Venice -> 45.4175761, 12.3683538
# Geocoded n. 481: Ponte Visconteo, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 482: Teatro Salieri, Legnago -> 45.1914252, 11.3074076
# Geocoded n. 483: Piazza Caduti, Mogliano Veneto -> 45.5611317, 12.2363049
# Geocoded n. 484: Monte Cristallo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 485: Villa Valle, Valdagno -> 45.6413213, 11.3040596
# Geocoded n. 486: Villa Pisani, Treviso -> 45.7444518, 11.9837692
# Geocoded n. 487: Museo Villa Bassi Rathgeb, Abano Terme -> 45.3603142, 11.7897833
# Geocoded n. 488: Corso del Popolo, Chioggia -> 45.2187118, 12.278491
# Geocoded n. 489: Museo del Precinema, Padua -> 45.4077172, 11.8734455
# Geocoded n. 490: Piazza Costituzione, San Bonifacio -> 45.3955369, 11.2695655
# Geocoded n. 491: Museo Civico, Belluno -> 46.1375185, 12.2181711
# Geocoded n. 492: Borghetto sul Mincio, Valeggio sul Mincio -> 45.3537509, 10.734546
# Geocoded n. 493: Gallerie dell'Accademia, Venice -> 45.4313662, 12.3280919
# Geocoded n. 494: Monte Cristallo, Cortina d'Ampezzo -> 46.5383332, 12.1373506
# Geocoded n. 495: Museo della Pesca, Peschiera del Garda -> 45.4389454, 10.6920171
# Geocoded n. 496: Villa Querini, Mestre -> 45.4943063, 12.2418053
# Geocoded n. 497: Chiesa di San Domenico, Chioggia -> 45.218894, 12.2785805
# Geocoded n. 498: Museo del Naviglio, Dolo -> 45.4234356, 12.0743252
# Geocoded n. 499: Museo Civico di Noale, Noale -> 45.550156, 12.0720437
# Geocoding complete and saved to veneto_events_geocoded_structured.json

# %% [markdown]
# #### 📦 Qdrant Vector DB Upsert
#
# This section uploads geocoded Veneto event data into a Qdrant vector database.
#
# Steps:
# - Load environment variables from `.env`
# - Load geocoded events from `veneto_events_geocoded_structured.json`
# - Check or create the `veneto_events` collection in Qdrant (2D vector + geo index)
# - Prepare points with vector coordinates and geo payload
# - Upsert all event points to the Qdrant collection
# - Print the number of events uploaded
#
# Enables fast geospatial search and analysis

# %%
import json
import os
from dotenv import load_dotenv
from qdrant_client import QdrantClient
from qdrant_client.http.models import PointStruct, VectorParams, Distance

# Load environment variables
load_dotenv(dotenv_path="../.env")
#load_dotenv(dotenv_path="..\\superlinked\\.env")

QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")

client = QdrantClient(
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
    timeout=2000000
)

# client = QdrantClient(url=QDRANT_SERVER, api_key=QDRANT_API_KEY, timeout=200000)

# Load events data
with open("veneto_events_geocoded_structured.json", "r", encoding="utf-8") as f:
    events = json.load(f)["events"]

collection_name = "veneto_events"

# Check if collection exists
collections = [col.name for col in client.get_collections().collections]

if collection_name not in collections:
    client.create_collection(
        collection_name=collection_name,
        vectors_config=VectorParams(size=2, distance=Distance.COSINE)
    )
    # Explicitly create geo index for location field
    client.create_payload_index(
        collection_name=collection_name,
        field_name="location",
        field_schema="geo"
    )
else:
    # Safe to call repeatedly to ensure index exists
    client.create_payload_index(
        collection_name=collection_name,
        field_name="location",
        field_schema="geo"
    )

# Prepare points with vector and geo payload
points = []
for event in events:
    lat = event["location"].get("latitude")
    lon = event["location"].get("longitude")
    if lat is None or lon is None:
        continue
    payload = event.copy()
    payload["location"]["lat"] = lat
    payload["location"]["lon"] = lon
    payload["location"].pop("latitude", None)
    payload["location"].pop("longitude", None)

    points.append(
        PointStruct(
            id=int(event["id"]),
            vector=[lon, lat],
            payload=payload
        )
    )

# Upsert points
client.upsert(
    collection_name=collection_name,
    points=points
)

print(f"Uploaded {len(points)} events to Qdrant collection '{collection_name}'")
# Out:
# Uploaded 497 events to Qdrant collection 'veneto_events'

# %%
# !pip install qdrant_client
# Out:
# Requirement already satisfied: qdrant_client in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (1.15.1)
# Requirement already satisfied: grpcio>=1.41.0 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from qdrant_client) (1.73.0)
# Requirement already satisfied: httpx>=0.20.0 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from qdrant_client) (2.3.0)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from qdrant_client) (2.10.1)
# Requirement already satisfied: protobuf>=3.20.0 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from qdrant_client) (6.31.1)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from qdrant_client) (2.11.7)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from qdrant_client) (2.5.0)
# Requirement already satisfied: anyio in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (4.9.0)
# Requirement already satisfied: certifi in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (1.0.9)
# Requirement already satisfied: idna in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (1.3.1)
